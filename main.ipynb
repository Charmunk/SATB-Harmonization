# %% [markdown]
# ## SATB Harmoniztion

# %%
import numpy as np
from scipy.signal import stft, resample_poly
from scipy.signal.windows import hann
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
import IPython.display as ipd

# %% [markdown]
# Import the dataset

# %% [markdown]
# Figuring out which chord a song is in based on the soprano, alto, tenor, and bass parts

# %% [markdown]
# Chord-to-chord markov model, but with transition probabilities depending on the two previous states

# %% [markdown]
# Calculate the probability of S given the chord info

# %% [markdown]
# Turn that around, get P(chord|S) using Bayes' theorem perhaps?

# %% [markdown]
# Combine the pieces, try to calculate P(ATB|S, chord). Sample from it instead of taking the max? Method still unclear.
