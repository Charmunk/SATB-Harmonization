# %% [markdown]
# # Soprano and Previous Chord to Current Chord Transition Matrix

# %%
from s_to_chord_transition import s_to_chord

# %%
dataset_dir = "dataset/1/train"
s_to_chord(dataset_dir, numChords=21, numNotes=128, debug=True)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 dataset_dir = "dataset/1/train"
# ----> 2 s_to_chord(dataset_dir, numChords=21, numNotes=128, debug=True)
#
# File ~/Documents/SATB-Harmonization/s_to_chord_transition.py:33, in s_to_chord(dataset_dir, numChords, numNotes, debug)
#      23 '''
#      24 Turns a sequence of soprano notes into a sequence of chords.
#      25
#    (...)     30     - sequence of chords
#      31 '''
#      32 chord_to_s, prevchord_to_s = getChordToS(dataset_dir, numChords=21, numNotes=128, debug=False)
# ---> 33 prevchord_to_chord = chord_to_chord_mm(dataset_dir)
#      35 #element-wise multiplication and division
#      36 s_to_chord_matrix = chord_to_s * prevchord_to_chord / prevchord_to_s
#
# File ~/Documents/SATB-Harmonization/chord_to_chord_mm.py:71, in chord_to_chord_mm(dataset_dir)
#      69     continue
# ...
